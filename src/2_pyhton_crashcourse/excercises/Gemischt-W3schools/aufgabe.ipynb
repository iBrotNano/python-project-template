# %% [markdown]
# - Arbeite die Übungen auf w3schools durch

# %% [markdown]
# ## Listen
# https://www.w3schools.com/python/exercise.asp?x=xrcise_lists1

# %% [markdown]
# ## List Comprehension
# https://www.w3schools.com/python/exercise.asp?x=xrcise_lists_comprehension1

# %% [markdown]
# ## Strings
# https://www.w3schools.com/python/exercise.asp?x=xrcise_strings1

# %% [markdown]
# ## Dictionaries
# https://www.w3schools.com/python/exercise.asp?x=xrcise_dictionaries1
