# %% [markdown]
# #### Log-Analyse
# - Hacker haben den Administrationsbereich einer Website eines Kunden im Visier, Sie versuchen mit "Brute Force" das Administrations-Passwort zu erraten.
# - Versuche anhand der `access_logs` die ip-Addressen der Angreifer zu finden, damit Sie über die Firewall geblockt werden können.
# - Welche ip taucht am häufigsten in den Logs auf?

# %%
f = open("access_log", "r")
log_file = f.read() # log_file enthält access_log als str

#
