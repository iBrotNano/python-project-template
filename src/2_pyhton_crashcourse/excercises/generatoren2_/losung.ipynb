# %% [markdown]
# - Schreibe eine Generator-Funktion welche alle Permutationen eines Stings liefert
# - Gib die Ergebnisse aus
# - es bietet sich eine rekursive-Funktion an
# - recherchiere notfalls eine Lösung

# %%
def string_permutations(string):
    if len(string) <= 1:
        yield string
    else:
        for i in range(len(string)):
            current_char = string[i]
            remaining_chars = string[:i] + string[i+1:]
            for permutation in string_permutations(remaining_chars):
                yield current_char + permutation
# User-Input
input_string = input("Input a string: ")

# permutations Generator, könnte auch 
permutations_gen = string_permutations(input_string)

# Generate and print all permutations
print("All permutations of", input_string + ":")
for permutation in permutations_gen:
    print(permutation, end = ", ")


#print(*permutations_gen,sep=", ")
# Out:
# All permutations of abc:
# abc, acb, bac, bca, cab, cba

# %%
"abc, derwr,".rstrip(',')
# Out:
# 'abc, derwr'
