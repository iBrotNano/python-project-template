# %% [markdown]
# - Schreibe  eine Generatorfunktion, welche eine Zahlenreihe "x hoch 3" mit x = 1,.. ,n sukzessive erzeugt
# - verwende dazu die Benutzer-Eingabe n (int) welche beim Funktions-Aufruf verwendet werden soll um die Zahlen-Reihe zu begrenzen
# - Gebe die Ergebnisse in eine for-Schleife aus
