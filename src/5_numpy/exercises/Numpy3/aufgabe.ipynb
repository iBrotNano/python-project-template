# %% [markdown]
# ## Numpy mit Bildern
# - Benötigt wird die pillow bibliothek

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /Volumes/KINGSTON/_cimdata_datascience_2025c/5_numpy/.venv/lib/python3.13/site-packages (12.0.0)

# %% [markdown]
# ## Beispiel: Ein weißes Rechteck ins Bild zeichnen

# %%
from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #

print(type(im))
print(im.dtype)
print(im.shape)
print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz

# Bsp ein Rechteck zeichnen:
im[50:165,20:175] = [255,100,255] # Farbe als RGB

# Bild speichern
pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)
# [225 202 186]

# %% [markdown]
# # Übungs Aufgaben:
#
# 1. Zeichne einen 10 Pixel breiten weißen Rand um das Bild
# 2. spiegel das Bild jeweils horizontal und vertikal
# 3. füge ein zweites Bild ein
# 4. Eigene Recherche: Füge zwei gleiche Bilder aneinander mit der Funktion `concatenate`
# (<https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html>)
# 5. rotiert das Bild  um 90 Grad und benutze dabei die Funktion numpy.rot90()
# # (<https://numpy.org/doc/stable/reference/generated/numpy.rot90.html>)
