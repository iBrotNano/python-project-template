# %% [markdown]
# # Erzeuge ein Array welches auf dem Intervall 0 bis 10, 30 Werte gleichmäßig verteilt

# %%
import numpy as np

# %% [markdown]
# # Erzeuge ein Array mit np.arange(), welches eine shape (2,3,4) hat

# %% [markdown]
# - Lade die `data.csv`in ein Numpy-Array
# - ersetze fehlende Werte mit 0.0

# %%
data = np.genfromtxt('data.csv', delimiter=',', filling_values=0.0, skip_header=1)

# %% [markdown]
# - Lade die `data2.csv`in ein Numpy-Array
# - ersetze dabei fehlende Werte mit dem Durchschnitts-Wert/Arithmetischen-Mittelwert der jeweiligen Spalte

# %% [markdown]
# - Wie lautet das "dtype-Kürzel" folgender Arrays?

# %%
arr = np.array(['Pizza', 'Spagetti', 'Lamb-Ragout'])
arr2 = np.array([22,333,1,4],dtype='S')

# %% [markdown]
# - Welche Shape haben die mehrdimensionalen Arrays A,B,C,D,E ?
# - Überlege auch wie die mehrdimensionalen Arrays aussehen, also aus welchen Einträgen sie bestehen.

# %%
arr_3d =  np.arange(1,9).reshape((2,2,2))
print(arr_3d)

A = arr_3d[:,1,:]
A.shape

B = arr_3d[0,:,:]
B.shape

C = arr_3d[0,1,:]
C.shape

D = arr_3d[0,1,0]
D.shape
D

E = arr_3d[0,:1,0]
E.shape
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# (1,)
