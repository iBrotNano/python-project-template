# %% [markdown]
# - Bestimme für folgende Arrays die Dimension und Shape
# - Versuche es erstmal ohne die Hilfe von Python

# %%
import numpy as np

arr1 = np.array([[1,2],[3,4]])

# %%
arr2 = np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])

# %%
arr3 = np.array([[[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]],[[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]],[[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]]])
