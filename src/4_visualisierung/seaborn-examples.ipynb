# %% [markdown]
# # Ein Beispiel für die Visualsierungs-Möglichkeiten mit Seaborn
#
# * https://seaborn.pydata.org/tutorial/introduction.html

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Seaborn erzeugt "attraktive" Diagramme

# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np
#seaborn.set()  # Deprecated (!) stattdessen plot style
#seaborn.set_theme()

#plt.style.use("seaborn-v0_8-whitegrid")
#plt.style.use("seaborn-v0_8-deep")
plt.style.use("seaborn-v0_8-pastel")

# Seaborn zurücksetzen
#seaborn.reset_defaults()


ywerte = np.random.randint(0,100,7)
xwerte = ["spd", "cdu", "afd", "grüne", "linke", "Frei Wähler", "Basis"]

plt.bar(xwerte, ywerte)
plt.xlabel("X-Werte")
plt.ylabel("Y-Werte")
plt.show()

# %%
# Import seaborn
import seaborn as sns
import pandas as pd

#penguins = sns.load_dataset("penguins") # Pandas Dataframe
penguins = pd.read_csv('csv/penguins.csv')

#display(penguins.head(3))
#penguins.head(4)

#hue: Semantic variable that is mapped to determine the color of plot elements.

sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

#display(penguins)

# %% [markdown]
# #### Hinweis:
# Wird ein Diagramm nicht angezeigt, hilft manchmal die Command-Palette (cmd/ctrl + shift + p ) => "Developer: Reload Window"

# %% [markdown]
# #### Varianten des sns.jointplot()

# %%
#
#sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", kind="hex")
#sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# Kombination
g = sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm",hue="species")
#sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)
