# %% [markdown]
# ### Daten visualisieren
# - Visualisierung ist ein wichtiges Werkzeug in _Data Science_
# - Es gibt zwei Anwendungen  für die Visualisierung von Daten
#     - Daten erkunden
#     - Daten kommunizieren
# - Es gibt eine große Auswahl von Tools zur Visualisierung, - wir werden die Python-Bibliothek Matplotlib  (https://matplotlib.org/) verwenden.
# - Mit Matplotlib lässt sich eine Vielzahl von verschiedenen Diagrammen erstellen. Wir werden uns zunächst Balkendiagramme, Liniendiagramme und Scatterplots anschauen
# - welche Art Diagramm wir einsetzen hängt von den jeweiligen Daten ab

# %%
# Installation
# %pip install matplotlib

# %%
#Testen
import matplotlib
matplotlib.__version__

# %% [markdown]
# - `pyplot` verwaltet intern den Zustand eines Diagramms, welches Schritt für Schritt aufgebaut wird.
# - Am ende wird das Diagramm mittels `show()` angezeigt oder mit `savefig`gespeichert
# - Ein Linien-Diagramm/Line-Chart kann mit der Methode `plt.plot()` erzeugt werden

# %%
#Ein Line-Chart (Linien-Diagramm)
# Bruttoinlandsproduct gdp usa
from matplotlib import pyplot as plt

# %% [markdown]
# # Beispiel "Plot" von Mathematischen Funktionen
#
# * Ein Graph einer Funktion lässt sich in wenigen Zeilen erstellen
# * dazu werden Paare von Werten für die x und y Werte der Funktion benötigt
# * also f(x) = y
# * wir benötigen also x-Werte für die wir den  y-Wert mittels der Funktions-Gleichung ausrechnen.
# - also wenn f(x) = sin(x) gilt:
#   f(1)= sin(1)  daraus folgt daß der Graph an der Stelle 1 den y Wert sin(1) hat  und sin(1)= 0.8414709848078965
#   f(2)= sin(2) = 0.9092974268256817
#   ..

# %%
#Ein Line-Chart (Linien-Diagramm)

# %%
#Ein Line-Chart (Linien-Diagramm)

# %% [markdown]
# #### Mehrere Graphen in einem Diagramm

# %%
#Ein Line-Chart (Linien-Diagramm)

# %% [markdown]
# ## Liste der möglichen Marker,Line-Styles, Format-Strings & Farben
# ```text
# Markers
# '.' 	point marker
# ',' 	pixel marker
# 'o' 	circle marker
# 'v' 	triangle_down marker
# '^' 	triangle_up marker
# '<' 	triangle_left marker
# '>' 	triangle_right marker
# '1' 	tri_down marker
# '2' 	tri_up marker
# '3' 	tri_left marker
# '4' 	tri_right marker
# 's' 	square marker
# 'p' 	pentagon marker
# '*' 	star marker
# 'h' 	hexagon1 marker
# 'H' 	hexagon2 marker
# '+' 	plus marker
# 'x' 	x marker
# 'D' 	diamond marker
# 'd' 	thin_diamond marker
# '|' 	vline marker
# '_' 	hline marker
#
# Line Styles
# '-' 	solid line style
# '--' 	dashed line style
# '-.' 	dash-dot line style
# ':' 	dotted line style
#
# Format-Strings:
#
# 'b'    # blue markers with default shape
# 'or'   # red circles
# '-g'   # green solid line
# '--'   # dashed line with default color
# '^k:'  # black triangle_up markers connected by a dotted line
#
#
# Farb-Abkürzungen:
#
# 'b' 	blue
# 'g' 	green
# 'r' 	red
# 'c' 	cyan
# 'm' 	magenta
# 'y' 	yellow
# 'k' 	black
# 'w' 	white
# ```

# %% [markdown]
# ### Autoscale + Koordinatenachsen konfigurieren
#
# - plt.autoscale
# - plt.margins: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.margins.html
# - plt.axhline & plt.axvline (Linie Horzontal & Vertikal)

# %%
#Ein Line-Chart (Linien-Diagramm)

# %% [markdown]
# ## Bar-chart (Balkendiagramm)

# %%
## Barchart (Balkendiagramm)

# %% [markdown]
# # Ein Barchart aus einer csv Datei erzeugen
#
# - Körpergröße der US-Präsidenten in einem Balkendiagramm darstellen

# %%
#Körpergröße der US-Präsidenten

# %% [markdown]
# ## Scatterplots

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Colormaps

# %%
# Colormaps 1

# %%
# Colormaps 2

# %% [markdown]
# #### Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Numpy und Matplot
# - NumPy ist eine Python-Bibliothek, die zum Arbeiten mit Arrays verwendet wird. Es verfügt auch über Funktionen für die Arbeit im Bereich der linearen Algebra, Fourier-Transformation und Matrizen
#
# - Meist werden statt Python-Listen, Numpy-Arrays verwendet.
# Für den Moment kann man sich diese Arrays wie Listen vorstellen:
# np.array([0,6,5]) "<=>" [0,6,5]
# - Alle Elemente sind bei Numpy-Arrays vom gleichen Typ
# - Matplotlib kann auch mit Numpy-Arrays umgehen, - man kann die Listen i.d.r  mit Numpy-Arrays ersetzen

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Plot in Datei speichern (png)

# %%
#fig.savefig("3d-plot") # Plot in Datei speichern

# %% [markdown]
# Animation:
# - https://medium.com/@pnpsegonne/animating-a-3d-scatterplot-with-matplotlib-ca4b676d4b55
# - https://towardsdatascience.com/animations-with-matplotlib-d96375c5442c
