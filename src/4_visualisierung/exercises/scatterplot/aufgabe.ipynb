# %% [markdown]
# ### Scatterplots
#
# Schreibe ein Python-Script, um ein Scatterplot (Streudiagramm) zu zeichnen, das eine zufällige Verteilung in X und Y annimmt (Gleichverteilung) und gegeneinander aufträgt.
# - verwende z.B. `random.random()`
#
# Beispiel Ausgabe:
#
# ![](img/scatterplot.png)
