# %% [markdown]
# ## Verwende ein weiteres Model von google ai:
# - Imagen: https://ai.google.dev/gemini-api/docs/imagen?hl=de
# - Veo: https://ai.google.dev/gemini-api/docs/video?hl=de&example=dialogue
# - Lyra: https://ai.google.dev/gemini-api/docs/music-generation?hl=de
