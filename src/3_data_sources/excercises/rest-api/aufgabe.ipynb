# %% [markdown]
# # REST -API
#
# - Suche eine REST-API beispielsweise auf https://www.geeksforgeeks.org/blogs/free-apis-list
# - Frage Daten von der API ab
# - schreibe die Daten, wenn möglich, in eine csv-Datei
